# %% [markdown]
# <a href="https://colab.research.google.com/github/menpente/sandbox/blob/main/google_trends.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pytrends
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytrends
#   Downloading pytrends-4.9.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from pytrends) (4.9.2)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.8/dist-packages (from pytrends) (1.3.5)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.8/dist-packages (from pytrends) (2.25.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25->pytrends) (2022.7.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25->pytrends) (1.21.6)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.0->pytrends) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.0->pytrends) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.0->pytrends) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.0->pytrends) (4.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25->pytrends) (1.15.0)
# Installing collected packages: pytrends
# Successfully installed pytrends-4.9.0

# %%
from pytrends.request import TrendReq

pytrends = TrendReq(hl='es-ES')

# %%
import pandas as pd
df = pd.read_csv('ongs.csv')
ongs = df.nombre.to_list()

# %%
ongs
# Out:
# ['“JUNEREN HEGOAK” ASOCIACIÓN DE APOYO A NIÑOS Y NIÑAS CON ENFERMEDAD Y A SUS FAMILIAS',
#  '4 Patas Jumilla',
#  'A.C.M. ROCK MACHINE',
#  'ACASC',
#  'Acción y Reacción Animal Cantabria',
#  'Acción, Desarrollo y Sostenibilidad',
#  'ACINTEA',
#  'ADANA',
#  'ADAYRA Adopciones',
#  'Adopta un Amigo Mallorca',
#  'AESRT',
#  'AFANION - Niños con Cáncer',
#  'Àgora Republicana',
#  'ALBA Asociación para la Liberación y Bienestar Animal',
#  'ALMA -  Asociación de Lucha contra el Maltrato Animal',
#  'Alternativa en Marcha',
#  'AMAI TLP',
#  'Amar Dragoste',
#  'Amics dels Animals de la Noguera',
#  'AMICS DELS GATS DE LA FLORESTA',
#  'AMIGOS DE MONKOLE',
#  'AML (EN CONSTITUCION)',
#  'Amnistia Internacional del Estado Español',
#  'Animals sense Sostre',
#  'APA La Sonrisa Peluda',
#  'Apadif Ciudad Real',
#  'APAGUAS',
#  'APERFOSA',
#  'APNABI LAN Autismo Bizkaia Empleo',
#  'Arrels Marines',
#  'Arte Paliativo',
#  'ASOC 4 paws adoptions',
#  'Asoc A Favor De Personas Con Discapacidad Intelectual De Granada',
#  'ASOC AMC ARTROGRIPOSIS MULTIPLE CONGENITA ESPANA',
#  'Asoc Atlas de Adopción y Acogimiento',
#  'ASOC COLECTIVO ANIMALISTA DE LEGANES',
#  'Asoc Collective Calling',
#  'Asoc Cultural Sesayo',
#  'ASOC DE MIGRANTES DE GALICIA - AMIGA',
#  'Asoc DogPoint',
#  'ASOC HELP DE DENIA DISTRITO',
#  'Asoc Jupiterfab',
#  'Asoc Meigas da Rua',
#  'ASOC ONGANANDA',
#  'Asoc para la protección animal Cantileros',
#  'Asoc Protectora de Animales Pichu Animales',
#  'ASOC PROTECTORA DE LOS GATOS GATITUD',
#  'ASOC SONRISAS AZULES VERDES Y NARANJAS',
#  'Asoc Tajibo',
#  'ASOC VOZ Y DIFUSION DEL ANGIOSARCOMA',
#  'ASOC. PRO ANIMALES MALLORCA',
#  'ASOC. PROTECTORA DE ANIMALES RESCATE ANIMAL GRANADA',
#  'Asociació Cergat Corbera de Llobregat. Per la Defensa dels Gats Ferals',
#  'Asociacion 2Europia',
#  'Asociación Actives Educación',
#  'Asociación Afanias Castellón',
#  'Asociación ALMA contra la Violencia de Género',
#  'Asociación AMAFI',
#  'Asociación Amigos de Ositeti',
#  'Asociación Andaluza Corazón y Vida',
#  'Asociación Andaluza de Familias Solidarias',
#  'Asociación Andaluza Instituto Formación teatral IN FORTE ATOPÍA',
#  'Asociacion Animalista Donkey Dreamland Mijas',
#  'Asociación ArteSOSlidario',
#  'Asociación ASMD España',
#  'Asociación Autofabricantes',
#  'ASOCIACION AVENTURA 2000',
#  'Asociación Ayúdame3D',
#  'Asociación Ayudar Jugando',
#  'Asociación Banco de Alimentos de Cáceres',
#  'Asociación Banco de Alimentos Solidario Madrid Animalista Perros Gatos y más',
#  'ASOCIACION B-LIFE DEPORTE E INCLUSION',
#  'Asociación Building Bridges',
#  'ASOCIACION CANCER DE PANCREAS',
#  'Asociación Cero Negativo',
#  'Asociacion Citizens Advice Bureau Spain',
#  'Asociación Ciudad de la Esperanza',
#  'Asociación Colectivo CreceT',
#  'Asociación Comunidad Hispanohablante de NVDA',
#  'Asociación Conquistando Escalones',
#  'Asociación Contemplare',
#  'Asociación Creando Huellas',
#  'Asociación Cultural Amigos de Radio Republicana',
#  'Asociación Cultural Arturo Cerdá y Rico',
#  "Asociación Cultural Let's Jazz - ACL JAZZ",
#  'Asociación Cultural Sefarad Aragón',
#  'Asociación Cultural The Goingman Camera Collection',
#  'Asociación cultural y peña sanferminera Pompaelo',
#  'Asociacion Cultural, Recreativa y Obra Social Amparo de Maria',
#  'Asociación de Esclerosis Múltiple de Navarra',
#  'Asociación de Esclerosis Múltiple de Toledo',
#  'ASOCIACIÓN DE FAMILIARES Y AMIGOS DE PERSONAS CON DISCAPACIDAD INTELECTUAL',
#  'Asociacion de Naturalistas del Sureste (ANSE)',
#  'Asociación de Voluntarios por el Bienestar Animal de Láchar y Peñuelas',
#  'Asociación Defensa Animal Torrent-ADAT',
#  'Asociación DICO',
#  'Asociación EriSOS',
#  'ASOCIACIÓN ESPAÑA CON ACNUR',
#  'Asociación Española contra el cáncer',
#  'Asociación Española de Fundraising',
#  'Asociación Española de Lacrosse',
#  'Asociación Española de Naprotecnología',
#  'Asociación Española de Profesionales de Personas Altamente Sensibles',
#  'ASOCIACIÓN ESPAÑOLA DE SÍNDROME DE RETT - AESR',
#  'Asociacion Española Fotografos de Vida',
#  'Asociación FEEL',
#  'Asociación Generación o2',
#  'Asociación Girasol',
#  'Asociación Help Xènia',
#  'Asociación Icono Fátima',
#  'Asociación Innovacion y Derechos Humanos',
#  'Asociación Intramurs',
#  'Asociación Justicia Poética',
#  'ASOCIACION KARIBIA',
#  'Asociación Kudwa',
#  'ASOCIACIÓN LOGOS PROJECTES SOCIALS',
#  'ASOCIACIÓN LUMA',
#  'Asociacion Madrid a Tempo',
#  'Asociación Mamás en acción',
#  'Asociación Miradas que Hablan Duplicación Mecp2',
#  'Asociación Murciana de Esclerosis Múltiple (AMDEM)',
#  'Asociación Música para Despertar',
#  'Asociación Paul Venezuela',
#  'Asociación Peregrinos del Camino de El Mensaje de Silo',
#  'Asociacion pola protección animal Abeiro',
#  'ASOCIACION POR LA INTERMEDIACION E INTEGRACION SOCIAL AILIS',
#  'ASOCIACIÓN POR UN MUNDO MÁS JUSTO Y SOLIDARIO ESTRELLA ONG',
#  'Asociación Protectora Animalejos Calalberche',
#  'Asociación Protectora de Animales "El Capricho"',
#  'Asociación Protectora de Animales de Cambados',
#  'ASOCIACION PROTECTORA DE ANIMALES DEL MORRAZO',
#  'Asociación Pueblos Vivos Cuenca',
#  'Asociación Run4Life',
#  'Asociación Santuario Animal Gafi',
#  'Asociacion Semillistas',
#  'Asociación Síndrome  Phelan Mcdermid',
#  'ASOCIACIÓN SÍNDROME ANGELMAN',
#  'Asociación Síndrome Shy Drager-Atrofia Multisistémica ASYD',
#  'Asociacion Soberania Energetica (Light Humanity)',
#  'ASOCIACIÓN SOCIAL DAMARK NO GUBERNAMENTAL HUMANITARIA',
#  'ASOCIACION SOCIO-CULTURAL HOPE HOME',
#  'Asociación Somos Manada',
#  'Asociacion SUMAS',
#  'Asociacion SuperHeroes Un Niño Una Sonrisa',
#  'Asociacion Tardor',
#  'Asociación The Long Walk/La Gran Caminata',
#  'Asociación Tierra Sin Males',
#  'Asociación Trastorno Obsesivo Compulsivo Extremadura',
#  'Asociación Una Misión en Acción',
#  'Asociacion una sonrisa una ilusion',
#  'Asociación Vegan Point',
#  'Asociacion Ven da tu mano',
#  'Asociación Zicles Lighters Collectors',
#  'Asos Reserva Hijos del Bosque',
#  'ASSOCIACIO ACCION SENEGAL',
#  "ASSOCIACIO ACTIVA'TT PER LA SALUT",
#  'Associacio Cancer Support Mallorca',
#  'Associació Dignity.Cat de Sant Pere de Ribes',
#  'ASSOCIACIO GAVA GATS',
#  'ASSOCIACIO JAD COPRODUCTIONS PER DONES ADOLESCENTS I JOVES',
#  'ASSOCIACIÓ PER A LA SALUT FAMILIAR I COMUNITÀRIA VENTIJOL',
#  'ASSOCIACIO SARANA (REFUGI)',
#  'Associacio Sunshine Up Kids Home',
#  'Associacion Proyecto Caballo',
#  'ATADES',
#  'AUTRADE',
#  'Avanti Andalucía Siglo XXI',
#  'Banco de Alimentos del Segura',
#  'Bienesdar',
#  'Big Smiles',
#  'Bukaneros del rol - Asociación de juegos de rol de Vallecas',
#  'Canary Animal Rescue',
#  'CÁRITAS DIOCESANA DE IBIZA',
#  'Centro Académico Romano Fundación - CARF',
#  'CENTRO CRISTIANO FAMILIAR DE ALBACETE',
#  'CESAL',
#  'CIM Burkina',
#  'Cirujanos Ortopédicos de España para el Mundo COEM',
#  'Club Trial RC Mallorca',
#  'COGAM - Colectivo LGTB de Madrid',
#  'Comite Ciudadano Antisida del Campo de Gibraltar',
#  'COMUNIDAD RR ADORATRICES MALAGA',
#  'Confederación Autismo España',
#  'CRUZ ROJA ESPAÑOLA',
#  'Cuatro Huellas',
#  'DEBRA España',
#  'DEGATS Defensa Del Gats',
#  'DOG VIDA ASOCIACION',
#  'El Camí de la Solidaritat',
#  'El Sueño de Walter',
#  'EMACC - Esclerosis Múltiple Cartagena',
#  'Enach Asociación',
#  'ENCUENTRO MATRIMONIAL',
#  'Enlazando Vidas',
#  'Enrama',
#  'ensaia.',
#  'Equipo Europa',
#  'ESTRELLA DE LA MAÑANA',
#  'EXPOACCION ORGANIZACIÓN SOLIDARIA',
#  'Farmacéuticos Mundi',
#  'FEDERACIÓN PADRES DE NIÑOS CON CÁNCER',
#  'Federación SOS Racismo',
#  'FELGTBI',
#  'Flores de Kiskeya',
#  'Fontilles. Salud y desarrollo.',
#  'FORGE for humanity',
#  'Friends of Mazarron Animals',
#  'Frodeno Fund',
#  'Fundació ajudantajudar',
#  'Fundació Ave Maria',
#  'Fundació Catalana per la Paràlisi Cerebral',
#  'FUNDACIO GREENNOVA',
#  'FUNDACIÒ INTERNACIONAL MIQUEL VALLS',
#  'FUNDACIO NEN DEU',
#  'FUNDACIO PRIVADA BAYT AL THAQAFA',
#  'Fundació Privada Catalana per a la Prevenció de Residus i Consum responsable',
#  'Fundació Privada Lliga Catalana d’Ajuda Oncològica',
#  'Fundacio Privada Montserrat Caballé',
#  'Fundació Privada Pare Manel',
#  "Fundació Privada Tutelar de les Terres de l'Ebre",
#  'FUNDACIO PRIVADA UTOPIA',
#  'Fundació Projecte Miranda',
#  'Fundació Rif Tribes',
#  'Fundación 100 Vidas',
#  'Fundación 26 de Diciembre',
#  'Fundación Acción contra el Hambre',
#  'Fundacion ACOMPARTIR',
#  'Fundación Adsis',
#  'Fundación AISSE',
#  'Fundación ALADINA',
#  'FUNDACION AMASOL - AMASOL FAMILIAS MONOMARENTALES, MONOPARENTALES Y RECONSTITUIDAS',
#  'Fundación Amazonia',
#  'Fundación Ana Bella para la ayuda a mujeres maltratadas y madres separadas',
#  'Fundación ANAED',
#  'Fundación ANAR',
#  'Fundación ANSE',
#  'FUNDACION ASHA-KIRAN',
#  'Fundación Atyla international training ship Foundation',
#  'FUNDACION AYMY',
#  'Fundación Ayuda Una Familia Registro de Fundaciones de la Comunitat Valencia 604V',
#  'Fundación Benéfico Docente Docete Omnes',
#  'Fundación Cal Pau',
#  'Fundación centauro Quirón',
#  'FUNDACIÓN CENTRO DE POESÍA JOSÉ HIERRO',
#  'FUNDACION CENTRO ESPAÑOL DE SOLIDARIDAD DEL PRINCIPADODE ASTURIAS',
#  'Fundacion Ciencias de la Documentacion',
#  'Fundación Código V',
#  'Fundacion Contamos Contigo',
#  'Fundación CRIS de investigación para vencer el cáncer',
#  'Fundación Dalma',
#  'Fundación Dilaya',
#  'Fundación Diversión Solidaria',
#  'Fundación Ecomar',
#  'Fundación Efrat Espana',
#  'Fundación El Mundo del Superdotado',
#  'Fundación Elena Barraquer',
#  'FUNDACION EMALAIKAT',
#  'Fundacion Euro Eco Junior',
#  'Fundación Global Hub For The Common Good',
#  'Fundación Hay Salida',
#  'Fundación HelpAge International España',
#  'Fundación Human Appeal International',
#  'Fundación Informativos.Net',
#  'Fundación Inocente, Inocente',
#  'FUNDACIÓN JOSEP CARRERAS',
#  'FUNDACIÓN JUEGATERAPIA',
#  'Fundación Kick Out Plastic de la Comunidad Valenciana',
#  'FUNDACION KIRIRA',
#  'Fundación Kyrios de Apoyo Personal',
#  'Fundacion Laboratorio de Anatomia Animal',
#  'FUNDACION LIBELLAS',
#  'Fundación Lusekelo - Alegría',
#  'FUNDACION MAHASANDHI',
#  'Fundación Mascoteros',
#  'FUNDACION MENSAJEROS DE LA PAZ',
#  'FUNDACIÓN MENUDOS CORAZONES',
#  'Fundación Miaoquehago',
#  'Fundación No Somos Invisibles',
#  'Fundación Novaterra',
#  'FUNDACIÓN NUMEN',
#  'Fundación Oceana',
#  'Fundación Padre Arrupe',
#  'Fundación Padre Garralda Horizontes-Abiertos',
#  'Fundación PKU y Otros Trastornos Metabólicos Hereditarios',
#  'Fundación Porque Viven',
#  'FUNDACION PRASAD ESPAÑA',
#  'FUNDACION PRESBITERIANA DE LITERATURA REFORMADA',
#  'FUNDACION PRIVADA CARTA DE LA PAZ DIRIGIDA A LA ONU',
#  'Fundación Privada Kalida',
#  'Fundacion PROA (PRO-ACTIVA OPENARMS)',
#  'Fundacion Reserva Wild Forest',
#  'Fundacion Santa Maria de Toraya',
#  'Fundación Santuario Gaia',
#  'Fundacion Santuario Vegan',
#  'FUNDACION SOCA',
#  'Fundación Solidaridad Amaranta',
#  'Fundación SonÁngeles',
#  'Fundación Street Child España',
#  'Fundación Telefamilia',
#  'Fundación ThePinkForce',
#  'Fundación Vencer el Cáncer',
#  'FUNDACIÓN VISIÓN',
#  'Fundación Young Life',
#  'Fundación ZOO KOKI',
#  'GAB Grupo de Ayuda al perro Ratonero Bodeguero Andaluz',
#  'Gentinosina Social',
#  'Global Future of Work Foundation (GFWF)',
#  'Greco Paro',
#  'Health Impact',
#  'HomelessEntrepreneur',
#  'Iglesia Elan',
#  'Iglesia Evangelica Gente con Vida',
#  'Impacto solidario ONG',
#  'Instituto de Política Social Española',
#  'Instituto de Robótica para la Dependencia',
#  'Jeb Andrews Foundation',
#  'Kakolum',
#  'Kifkif, Asociación de Migrantes y Refugiados LGTBI',
#  'KMC España Centro de Meditación Kadampa',
#  'La CAJA DE LA PEQUEÑA SILVIA',
#  'La Fàbrica de Cinema Alternatiu de Barcelona',
#  'La Mano que Ayuda',
#  'Las Reinas Del Biberón',
#  'Last Chance Animal Rescue',
#  'Life Mu Ghetto',
#  'los gatitos de nia',
#  'MANKIND PROJECT ESPAÑA - MKP-ESPAÑA',
#  'Médicos con Iberoamérica Ibermed',
#  'Médicos del Mundo',
#  'Médicos Sin Fronteras',
#  'Mensajeros de la Paz',
#  'Mi Voz Por Tu Sonrisa',
#  'Mindalia.com',
#  'MISIONERAS CLARISAS DEL SANTISIMO SACRAMENTO',
#  'Montessori British',
#  'Movimiento Antiespecista Lleó',
#  'NEPAL SONRIE EDUVISION SPAIN',
#  'NINGUN NIÑO SIN SONRISA',
#  'O.N.G. Ajut i Solidaritat Makary-Blangoua',
#  'OAN International',
#  'Objetivo diagnostico asoc de personas sin diagnostico',
#  'ONG BONWE',
#  'ONG de desarrollo Fiet Gratia',
#  'ONG Grandes Amigos',
#  'Orche Nepal',
#  'Organitzacio No Governamental Provalores',
#  'PALIATIVOS SIN FRONTERAS',
#  'Pallapupas',
#  'Patronato de Torreciudad',
#  'PAWS A WHILE DOG RESCUE',
#  'Payasos Sin Fronteras',
#  'PLASTIC FREE PROJECT',
#  'PROTECTORA DE ANIMALES ALORADOGRESCUE',
#  'Proyecto Nueva Vida Animal',
#  'Red de Apoyo Canino',
#  'refugio de animales horse holidays tenerife',
#  'Refugio La vida color Frambuesa',
#  'Remar España',
#  'Santuario Alma Libertaria',
#  'Santuario Joplin',
#  'Santuritos',
#  'Saturdays.AI',
#  'Save the Children',
#  'Servicios Sociales Europeos',
#  'Smiles on the Way',
#  'SOCIEDAD DE SAN VICENTE DE PAÚL EN ESPAÑA',
#  'SOCIEDAD IBERISTA CULTURAL',
#  'Sociedad para el Estudio de los Cetáceos en el Archipiélago Canario',
#  "Societat Protectora d'Animals de Mataró",
#  'SOS 112 VAGABUNDOS',
#  'SOS COCKER ASOC ESPAñOLA PARA COCKERS SIN HOGAR',
#  'SOS Racismo Galicia',
#  'Sos Weimaraner.ORG',
#  'Special Olympics Aragón',
#  'Tamkeen Foundation',
#  'Telefono de la Esperanza',
#  'The Animal Collective',
#  'The Ricky Rubio Foundation',
#  'Trastorno del Espectro Autista Mesa de Ocaña',
#  'Turismo Solidario 2020',
#  'Une Dos Soledades',
#  'Union Internacional para la Defensa de los Motocic',
#  'United Way España',
#  'Universo Conectado',
#  'Videojuegos Sin Fronteras',
#  'Women Going Beyond']

# %%
from datetime import date
master_df = pd.DataFrame()
for ong in ongs:
  q = ong.lower()
  pytrends.build_payload(kw_list=[q], timeframe=f'2023-01-01 {date.today()}', geo='ES')
  time_df = (pytrends.interest_over_time())
  master_df = master_df.append(time_df)
# Out:
# ---------------------------------------------------------------------------
# TooManyRequestsError                      Traceback (most recent call last)
# <ipython-input-13-073270615556> in <module>
#       3 for ong in ongs:
#       4   q = ong.lower()
# ----> 5   pytrends.build_payload(kw_list=[q], timeframe=f'2023-01-01 {date.today()}', geo='ES')
#       6   time_df = (pytrends.interest_over_time())
#       7   master_df = master_df.append(time_df)
#
# /usr/local/lib/python3.8/dist-packages/pytrends/request.py in build_payload(self, kw_list, cat, timeframe, geo, gprop)
#     187         self.token_payload['req'] = json.dumps(self.token_payload['req'])
#     188         # get tokens
# --> 189         self._tokens()
#     190         return
#     191
#
# /usr/local/lib/python3.8/dist-packages/pytrends/request.py in _tokens(self)
#     193         """Makes request to Google to get API tokens for interest over time, interest by region and related queries"""
#     194         # make the request and parse the returned json
# --> 195         widget_dicts = self._get_data(
#     196             url=TrendReq.GENERAL_URL,
#     197             method=TrendReq.GET_METHOD,
#
# /usr/local/lib/python3.8/dist-packages/pytrends/request.py in _get_data(self, url, method, trim_chars, **kwargs)
#     157         else:
#     158             if response.status_code == status_codes.codes.too_many_requests:
# --> 159                 raise exceptions.TooManyRequestsError.from_response(response)
#     160             raise exceptions.ResponseError.from_response(response)
#     161
#
# TooManyRequestsError: The request failed: Google returned a response with code 429

# %%
master_df.to_csv('ong_google_trends.csv')
